# %%
# Common imports for ESBE setup-style notebooks (1/2/3/9).
# Heavy lifting lives in urbanopt_des and lib.helpers; this cell stays terse.

from lib.helpers import (
    DEFAULT_DOCKER_IMAGE_TAG,
    select_uo_class,
    setup_notebook_paths,
)

# ── Execution mode ───────────────────────────────────────────────────────────
# Set USE_DOCKER = True  to route uo commands through the Docker container.
# Set USE_DOCKER = False to use a locally installed URBANopt CLI.
USE_DOCKER = False
UO = select_uo_class(USE_DOCKER, DEFAULT_DOCKER_IMAGE_TAG)

# Autoreload dependencies while iterating on wrapper / helper code.
# %load_ext autoreload
# %autoreload 2

# %%
# Standard set of working-directory paths used by every notebook.
# Change this to keep models/results outside the notebook folder (recommended).
# Examples: "../esbe_2026" (one level up) or "esbe_2026" (inside this folder).
MODEL_OUTPUT_SUBDIR = "../test_activities"
paths = setup_notebook_paths(analysis_subdir=MODEL_OUTPUT_SUBDIR)
workdir = paths.workdir
analysis_dir = paths.analysis_dir
template_data_dir = paths.template_data_dir
num_usable_cores = paths.num_usable_cores

# update weather flag (optional)
update_weather_location = True
# Asheville 2304 HDD / 461 CDD vs Bergamo 2323 HDD / 499 CDD at base 18.3 C.
weather_override = (
    # ("USA_NC_Asheville.Rgnl.AP.723150_TMY3", "6A") if update_weather_location else None
    ("Lecco_IT_TMY", "6A") if update_weather_location else None
)
# Out:
# Working directory: /Users/nlong/working/urban-analysis/esbe
# template_data_dir: /Users/nlong/working/urban-analysis/esbe/data/templates
# analysis_dir: /Users/nlong/working/urban-analysis/test_activities
# Number of usable cores for parallel processing: 9

# %% [markdown]
# ### Run the class project versions

# %%
activity_dir = paths.activity_dir('class_version')

# Set up the coincident project (create + scenarios + update + parallel + weather + mappers).
uo_coincident = UO(activity_dir, "coincident", template_dir=template_data_dir)

# %%
# Run the coincident baseline scenario.
uo_coincident.run("class_project_coincident.json", "baseline_scenario.csv")
# Out:
# Simulating features of 'class_project_coincident.json' as directed by 'baseline_scenario.csv'...
#
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Using runner options from runner.conf file
# Initializing runner with dirname: '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident' and options: {:file_version=>"0.1.0", :max_datapoints=>1000000000, :num_parallel=>9, :run_simulations=>true, :verbose=>false, :gemfile_path=>"/Applications/URBANoptCLI_1.2.0/gems/Gemfile", :bundle_install_path=>"/Applications/URBANoptCLI_1.2.0/gems"}
# @bundle_without_string = ''
# Gemfile.lock exists
# needs_config = true
# needs_platform = false
# needs_update = true
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/1/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/1/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/1/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.336587 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/2/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/2/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/2/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.337198 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/3/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/3/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/3/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.337603 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/4/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/4/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/4/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.337980 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/5/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/5/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/5/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.338353 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/6/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/6/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/6/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.338745 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/7/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/7/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/7/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.339110 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/8/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/8/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/8/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.339475 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/9/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/9/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/9/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:24.339825 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/10/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/10/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/10/ is out of date, regenerating input files
# I, [2026-06-05T16:00:24.585444 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/11/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/11/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/11/ is out of date, regenerating input files
# I, [2026-06-05T16:00:24.839884 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/12/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/12/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/12/ is out of date, regenerating input files
# I, [2026-06-05T16:00:25.098989 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/13/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/13/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/13/ is out of date, regenerating input files
# I, [2026-06-05T16:00:25.354389 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/14/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/14/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/14/ is out of date, regenerating input files
# I, [2026-06-05T16:00:25.610969 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/15/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/15/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/15/ is out of date, regenerating input files
# I, [2026-06-05T16:00:25.865031 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/16/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/16/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/16/ is out of date, regenerating input files
# I, [2026-06-05T16:00:26.111936 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/17/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/17/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/17/ is out of date, regenerating input files
# I, [2026-06-05T16:00:26.358326 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/18/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/18/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/18/ is out of date, regenerating input files
# I, [2026-06-05T16:00:26.603229 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/19/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/19/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/19/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:26.604192 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/20/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/20/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/20/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:26.604654 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/21/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/21/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/21/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:26.605080 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/22/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/22/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/22/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:26.605477 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/23/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/23/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/23/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:00:26.605881 #6863]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/1/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/1/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/2/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/2/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/3/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/3/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/4/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/4/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/5/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/5/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/6/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/6/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/7/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/7/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/8/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/8/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/9/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/9/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/10/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/10/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/11/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/11/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/12/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/12/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/13/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/13/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/14/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/14/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/15/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/15/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/16/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/16/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/17/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/17/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/18/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/18/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/19/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/19/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/20/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/20/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/21/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/21/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/22/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/22/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/23/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/23/' out of date
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/4/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/4/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/6/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/6/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/1/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/1/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/9/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/9/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/2/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/2/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/7/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/7/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/5/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/5/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/3/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/3/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/8/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/8/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/10/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/10/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/11/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/11/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/12/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/12/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/13/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/13/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/14/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/14/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/15/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/15/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/16/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/16/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/17/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/17/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/18/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/18/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/19/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/19/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/20/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/20/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/21/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/21/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/22/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/22/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/23/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/baseline_scenario/23/in.osw.log"
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# Done Running Scenario
#
# Done

# %%
# Run the diverse baseline scenario.
uo_coincident.run("class_project_coincident.json", "classproject_scenario.csv")
# Out:
# Simulating features of 'class_project_coincident.json' as directed by 'classproject_scenario.csv'...
#
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Using runner options from runner.conf file
# Initializing runner with dirname: '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident' and options: {:file_version=>"0.1.0", :max_datapoints=>1000000000, :num_parallel=>9, :run_simulations=>true, :verbose=>false, :gemfile_path=>"/Applications/URBANoptCLI_1.2.0/gems/Gemfile", :bundle_install_path=>"/Applications/URBANoptCLI_1.2.0/gems"}
# @bundle_without_string = ''
# Gemfile.lock exists
# needs_config = true
# needs_platform = false
# needs_update = true
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/1/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/1/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/1/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.725314 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/2/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/2/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/2/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.726357 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/3/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/3/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/3/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.726982 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/4/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/4/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/4/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.727407 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/5/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/5/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/5/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.727811 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/6/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/6/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/6/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.728252 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/7/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/7/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/7/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.728665 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/8/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/8/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/8/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.729068 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/9/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/9/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/9/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:52.729492 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/10/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/10/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/10/ is out of date, regenerating input files
# I, [2026-06-05T16:14:53.000167 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/11/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/11/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/11/ is out of date, regenerating input files
# I, [2026-06-05T16:14:53.265023 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/12/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/12/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/12/ is out of date, regenerating input files
# I, [2026-06-05T16:14:53.530952 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/13/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/13/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/13/ is out of date, regenerating input files
# I, [2026-06-05T16:14:53.800295 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/14/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/14/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/14/ is out of date, regenerating input files
# I, [2026-06-05T16:14:54.075185 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/15/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/15/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/15/ is out of date, regenerating input files
# I, [2026-06-05T16:14:54.341048 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/16/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/16/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/16/ is out of date, regenerating input files
# I, [2026-06-05T16:14:54.604738 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/17/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/17/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/17/ is out of date, regenerating input files
# I, [2026-06-05T16:14:54.862314 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/18/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/18/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/18/ is out of date, regenerating input files
# I, [2026-06-05T16:14:55.172785 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/19/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/19/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/19/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:55.173503 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/20/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/20/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/20/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:55.174009 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/21/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/21/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/21/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:55.174452 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/22/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/22/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/22/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:55.175330 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/23/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/23/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/23/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:14:55.176046 #28306]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/1/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/1/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/2/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/2/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/3/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/3/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/4/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/4/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/5/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/5/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/6/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/6/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/7/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/7/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/8/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/8/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/9/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/9/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/10/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/10/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/11/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/11/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/12/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/12/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/13/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/13/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/14/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/14/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/15/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/15/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/16/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/16/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/17/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/17/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/18/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/18/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/19/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/19/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/20/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/20/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/21/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/21/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/22/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/22/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/23/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/23/' out of date
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/9/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/9/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/7/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/7/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/1/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/1/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/6/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/6/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/3/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/3/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/8/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/8/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/5/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/5/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/4/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/4/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/2/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/2/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/10/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/10/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/11/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/11/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/12/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/12/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/13/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/13/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/14/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/14/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/15/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/15/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/16/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/16/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/17/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/17/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/18/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/18/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/19/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/19/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/20/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/20/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/21/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/21/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/22/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/22/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/23/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario/23/in.osw.log"
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# Done Running Scenario
#
# Done

# %%
uo_coincident.run("class_project_coincident.json", "classproject_scenario0.csv")
# Out:
# Simulating features of 'class_project_coincident.json' as directed by 'classproject_scenario0.csv'...
#
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Using runner options from runner.conf file
# Initializing runner with dirname: '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident' and options: {:file_version=>"0.1.0", :max_datapoints=>1000000000, :num_parallel=>9, :run_simulations=>true, :verbose=>false, :gemfile_path=>"/Applications/URBANoptCLI_1.2.0/gems/Gemfile", :bundle_install_path=>"/Applications/URBANoptCLI_1.2.0/gems"}
# @bundle_without_string = ''
# Gemfile.lock exists
# needs_config = true
# needs_platform = false
# needs_update = true
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/1/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/1/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/1/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.329119 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/2/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/2/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/2/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.329816 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/3/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/3/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/3/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.330265 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/4/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/4/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/4/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.330734 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/5/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/5/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/5/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.331206 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/6/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/6/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/6/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.331683 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/7/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/7/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/7/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.332133 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/8/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/8/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/8/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.332725 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/9/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/9/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/9/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:29.333155 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/10/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/10/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/10/ is out of date, regenerating input files
# I, [2026-06-05T16:21:29.608547 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/11/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/11/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/11/ is out of date, regenerating input files
# I, [2026-06-05T16:21:29.911396 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/12/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/12/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/12/ is out of date, regenerating input files
# I, [2026-06-05T16:21:30.195631 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/13/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/13/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/13/ is out of date, regenerating input files
# I, [2026-06-05T16:21:30.463893 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/14/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/14/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/14/ is out of date, regenerating input files
# I, [2026-06-05T16:21:30.731331 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/15/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/15/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/15/ is out of date, regenerating input files
# I, [2026-06-05T16:21:30.989250 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/16/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/16/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/16/ is out of date, regenerating input files
# I, [2026-06-05T16:21:31.260829 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/17/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/17/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/17/ is out of date, regenerating input files
# I, [2026-06-05T16:21:31.559113 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/18/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/18/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/18/ is out of date, regenerating input files
# I, [2026-06-05T16:21:31.877522 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/19/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/19/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/19/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:31.878982 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/20/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/20/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/20/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:31.879569 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/21/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/21/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/21/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:31.880114 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/22/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/22/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/22/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:31.880711 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/23/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/23/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/23/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-05T16:21:31.881279 #43215]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/1/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/1/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/2/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/2/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/3/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/3/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/4/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/4/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/5/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/5/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/6/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/6/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/7/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/7/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/8/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/8/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/9/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/9/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/10/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/10/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/11/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/11/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/12/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/12/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/13/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/13/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/14/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/14/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/15/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/15/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/16/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/16/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/17/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/17/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/18/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/18/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/19/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/19/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/20/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/20/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/21/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/21/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/22/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/22/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/23/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/23/' out of date
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/9/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/9/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/4/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/4/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/8/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/8/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/1/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/1/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/6/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/6/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/2/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/2/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/7/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/7/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/3/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/3/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/5/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/5/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/10/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/10/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/11/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/11/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/12/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/12/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/13/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/13/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/14/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/14/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/15/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/15/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/16/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/16/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/17/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/17/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/18/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/18/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/19/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/19/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/20/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/20/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/21/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/21/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/22/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/22/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/23/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_scenario0/23/in.osw.log"
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# Done Running Scenario
#
# Done

# %%
# Post-process each scenario explicitly (including ad-hoc scenario files).
scenario_names = ["baseline_scenario", "classproject_scenario", "classproject_scenario0"]

for scenario in scenario_names:
    print(f"Processing scenario: {scenario}")
    uo_coincident.process_scenario("class_project_coincident.json", f"{scenario}.csv")

# Generates project-level comparison pages from scenarios known to the project setup.
uo_coincident.visualize_feature("class_project_coincident.json")

# Also generate per-scenario feature pages so ad-hoc scenarios are always available.
for scenario in scenario_names:
    print(f"Visualizing scenario-specific feature page: {scenario}")
    uo_coincident.visualize_scenario("class_project_coincident.json", f"{scenario}.csv")
# Out:
# Processing scenario: baseline_scenario
# Post-processing URBANopt results
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
#
# Done
#
#
# Processing scenario: classproject_scenario
# Post-processing URBANopt results
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
#
# Done
#
#
# Processing scenario: classproject_scenario0
# Post-processing URBANopt results
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
#
# Done
#
#
#
# Creating visualizations for all Scenario results
#
# Done
#
#
# Visualizing scenario-specific feature page: baseline_scenario
#
# Creating visualizations for all Scenario results
#
# Done
#
# Creating visualizations for Feature results in the Scenario
#
# Done
#
#
# Visualizing scenario-specific feature page: classproject_scenario
#
# Creating visualizations for all Scenario results
#
# Done
#
# Creating visualizations for Feature results in the Scenario
#
# Done
#
#
# Visualizing scenario-specific feature page: classproject_scenario0
#
# Creating visualizations for all Scenario results
#
# Done
#
# Creating visualizations for Feature results in the Scenario
#
# Done

# %%
# run the optimized-district - no new measures yet.

uo_coincident.run("class_project_coincident.json", "classproject_optimized.csv")
# Out:
# Simulating features of 'class_project_coincident.json' as directed by 'classproject_optimized.csv'...
#
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Using runner options from runner.conf file
# Initializing runner with dirname: '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident' and options: {:file_version=>"0.1.0", :max_datapoints=>1000000000, :num_parallel=>9, :run_simulations=>true, :verbose=>false, :gemfile_path=>"/Applications/URBANoptCLI_1.2.0/gems/Gemfile", :bundle_install_path=>"/Applications/URBANoptCLI_1.2.0/gems"}
# @bundle_without_string = ''
# Gemfile.lock exists
# needs_config = true
# needs_platform = false
# needs_update = true
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/1/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/1/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/1/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.908952 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/2/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/2/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/2/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.909720 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/3/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/3/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/3/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.910351 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/4/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/4/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/4/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.911025 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/5/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/5/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/5/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.911683 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/6/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/6/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/6/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.912188 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/7/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/7/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/7/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.924309 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/8/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/8/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/8/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.924932 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/9/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/9/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/9/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:43.925481 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/10/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/10/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/10/ is out of date, regenerating input files
# I, [2026-06-08T16:05:44.186126 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/11/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/11/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/11/ is out of date, regenerating input files
# I, [2026-06-08T16:05:44.450912 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/12/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/12/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/12/ is out of date, regenerating input files
# I, [2026-06-08T16:05:44.718809 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/13/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/13/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/13/ is out of date, regenerating input files
# I, [2026-06-08T16:05:44.966730 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/14/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/14/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/14/ is out of date, regenerating input files
# I, [2026-06-08T16:05:45.234212 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/15/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/15/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/15/ is out of date, regenerating input files
# I, [2026-06-08T16:05:45.494845 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/16/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/16/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/16/ is out of date, regenerating input files
# I, [2026-06-08T16:05:45.787453 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/17/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/17/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/17/ is out of date, regenerating input files
# I, [2026-06-08T16:05:46.042690 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/18/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/18/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/18/ is out of date, regenerating input files
# I, [2026-06-08T16:05:46.314511 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/19/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/19/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/19/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:46.315341 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/20/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/20/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/20/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:46.315834 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/21/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/21/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/21/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:46.316663 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/22/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/22/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/22/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:46.317380 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# run_dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/23/' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/23/' out of date
# simulation_dir /Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/23/ is out of date, regenerating input files
# Setting weather_file_name to Lecco_IT_TMY.epw as specified in the FeatureFile
# I, [2026-06-08T16:05:46.317882 #41017]  INFO -- : Emissions is not activated for this feature. Please set emissions to true in the the Feature properties in the GeoJSON file to add emissions results.
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/1/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/1/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/2/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/2/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/3/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/3/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/4/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/4/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/5/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/5/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/6/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/6/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/7/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/7/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/8/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/8/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/9/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/9/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/10/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/10/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/11/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/11/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/12/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/12/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/13/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/13/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/14/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/14/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/15/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/15/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/16/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/16/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/17/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/17/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/18/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/18/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/19/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/19/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/20/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/20/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/21/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/21/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/22/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/22/' out of date
# finished_job_path '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/23/finished.job' does not exist, simulation dir '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/23/' out of date
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/2/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/2/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/6/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/6/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/7/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/7/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/3/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/3/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/1/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/1/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/5/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/5/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/9/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/9/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/4/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/4/in.osw.log"
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/8/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/8/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/10/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/10/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/11/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/11/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/12/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/12/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/13/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/13/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/14/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/14/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/15/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/15/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/16/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/16/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/17/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/17/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/18/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/18/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/19/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/19/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/20/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/20/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/21/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/21/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/22/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/22/in.osw.log"
# DONE, result = true
# SYSTEM CALL:
# /Applications/URBANoptCLI_1.2.0/OpenStudio/bin/openstudio --bundle '/Applications/URBANoptCLI_1.2.0/gems/Gemfile' --bundle_path '/Applications/URBANoptCLI_1.2.0/gems' run -w '/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/23/in.osw' 2>&1 > "/Users/nlong/working/urban-analysis/test_activities/class_version/coincident/run/classproject_optimized/23/in.osw.log"
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# DONE, result = true
# Done Running Scenario
#
# Done

# %%
uo_coincident.process_scenario("class_project_coincident.json", "classproject_optimized.csv")
uo_coincident.visualize_scenario("class_project_coincident.json", "classproject_optimized.csv")
uo_coincident.visualize_feature("class_project_coincident.json")
# Out:
# Post-processing URBANopt results
# Defaulting to .bundle/install (and ignoring system wide: Bundler.configured_bundle_path.base_path=/Applications/URBANoptCLI_1.2.0/gems/ruby/3.2.0)
# Bundle final path is set to: /Applications/URBANoptCLI_1.2.0/gems
#
# Done
#
#
#
# Creating visualizations for all Scenario results
#
# Done
#
# Creating visualizations for Feature results in the Scenario
#
# Done
#
#
#
# Creating visualizations for all Scenario results
#
# Done
